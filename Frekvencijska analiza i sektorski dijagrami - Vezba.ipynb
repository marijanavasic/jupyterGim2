# %%
oceneInf = [3, 4, 5, 4, 5, 3, 4, 5, 2, 4, 5, 4, 5, 4, 2, 3, 1, 4, 5, 4, 3, 2, 3, 4, 5, 4, 5, 5, 4, 3]

# %%
ocena5 = oceneInf.count(5)
ocena4 = oceneInf.count(4)
ocena3 = oceneInf.count(3)
ocena2 = oceneInf.count(2)
ocena1 = oceneInf.count(1)
print("Ocenu 5 ima", ocena5, "ucenika")
print("Ocenu 4 ima", ocena4, "ucenika")
print("Ocenu 3 ima", ocena3, "ucenika")
print("Ocenu 2 ima", ocena2, "ucenika")
print("Ocenu 1 ima", ocena1, "ucenika")
print(ocena5, ocena4,ocena3,ocena2,ocena1)
# Out:
# Ocenu 5 ima 9 ucenika
# Ocenu 4 ima 11 ucenika
# Ocenu 3 ima 6 ucenika
# Ocenu 2 ima 3 ucenika
# Ocenu 1 ima 1 ucenika
# 9 11 6 3 1

# %%
ukupno = len(oceneInf)
print(ukupno)
# Out:
# 30

# %%
procenat5 = 100 * ocena5 / ukupno
procenat4 = round(100 * ocena4 / ukupno, 1) 
procenat3 = 100 * ocena3 / ukupno 
procenat2 = 100 * ocena2 / ukupno 
procenat1 = round(100 * ocena1 / ukupno,1)
print(procenat5, procenat4, procenat3, procenat2, procenat1)
print("Od ukupno ", ukupno, "ucenika, njih", procenat5, "% ima ocenu 5")
print("Od ukupno ", ukupno, "ucenika, njih", procenat4, "% ima ocenu 4")
print("Od ukupno ", ukupno, "ucenika, njih", procenat3, "% ima ocenu 3")
print("Od ukupno ", ukupno, "ucenika, njih", procenat2, "% ima ocenu 2")
print("Od ukupno ", ukupno, "ucenika, njih", procenat1, "% ima ocenu 1")
# Out:
# 30.0 36.7 20.0 10.0 3.3
# Od ukupno  30 ucenika, njih 30.0 % ima ocenu 5
# Od ukupno  30 ucenika, njih 36.7 % ima ocenu 4
# Od ukupno  30 ucenika, njih 20.0 % ima ocenu 3
# Od ukupno  30 ucenika, njih 10.0 % ima ocenu 2
# Od ukupno  30 ucenika, njih 3.3 % ima ocenu 1

# %%
import matplotlib.pyplot as plt

# %%
predmeti = ["mat", "srp", "eng", "inf", "fiz", "bio"]
ocene = [3, 2, 5, 5, 5, 4]

# %%
plt.bar(predmeti, ocene)
plt.title("Ocene na polugodistu")
plt.xlabel("Predmeti")
plt.ylabel("Ocene")
plt.show()
plt.close()

# %%
import matplotlib.pyplot as plt

# %%
frekvencije = [9, 11, 6, 3, 1]
ocene = [5,4,3,2,1]
izmestanje = [0.1, 0, 0, 0, 0]

# %%
plt.pie(frekvencije, labels=ocene, explode=izmestanje)
plt.title("Ocene iz informatike")
plt.show()
plt.close()

# %%
gas = ["Azot", "Kiseonik", "Argon", "Ugljen dioksid"]
zastupljenost = [70.08, 20.94, 0.93, 0.05]
izdvoji = [0, 0, 0.75, 0.75]

# %%
plt.pie(zastupljenost, labels=gas, explode=izdvoji)
plt.title("Sastav nase atmosfere")
plt.show()
plt.close()

# %%
kontinenti = ["Azija", "Afrika", "Evropa", "Juzna Amerika", "Severna Amerika", "Okeanija"]
brStanovnika = [4_584_807_072, 1_320_038_716, 743_102_600, 658_305_557, 366_496_802, 41_826_176]

# %%
ukupnoStanovnika = sum(brStanovnika)
print(ukupnoStanovnika)
# Out:
# 7714576923

# %%
procenatAzija = round(100 * 4_584_807_072 / ukupnoStanovnika,2)
procenatAfrika = round(100 * 1_320_038_716 / ukupnoStanovnika,2)
procenatEvropa = round(100 * 743_102_600 / ukupnoStanovnika,2)
procenatJuznaAmerika = round(100 * 658_305_557 / ukupnoStanovnika,2)
procenatSevernaAmerika = round(100 * 366_496_802 / ukupnoStanovnika,2)
procenatOkeanija = round(100 * 41_826_176 / ukupnoStanovnika,2)

procenti = [procenatAzija,procenatAfrika, procenatEvropa,procenatJuznaAmerika,procenatSevernaAmerika,procenatOkeanija]
print(procenti)
# Out:
# [59.43, 17.11, 9.63, 8.53, 4.75, 0.54]

# %%
plt.pie(procenti, labels=kontinenti)
plt.title("Procenat stanovnika planete po kontinentima")
plt.show()
plt.close()
